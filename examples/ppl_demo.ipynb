# %%
# %matplotlib inline
import prettyplot as ppl
import matplotlib.pyplot as plt
import random

from palettable.tableau import Tableau_10

# %%
fig, axs = plt.subplots(figsize=(9,6.5), ncols=2)
ppl.make_ax_dark(axs[0])
xs = range(0, 11)

ppl.remove_spines(axs[1], ["right", "top"])
for i, c in enumerate(Tableau_10.hex_colors):
    ys = [(i+1)*x for x in xs]
    for ax in axs:
        
        ax.plot(xs, ys, c=c)
        ax.set_xlim([0, 10])
        ax.set_title("HELVETICA", color=ppl.steel_blue)
